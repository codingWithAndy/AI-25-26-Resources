# %% [markdown]
# # Session 1 – Introduction to Python: Student Tasks
#
# **Module:** CPU5006-20 Artificial Intelligence
# **Session:** 1 of 12
# **Student name:** ____________________
# **Date:** ____________________
#
# ## How to use this notebook
# Work through the tasks in order.
# Write your answers in the code cells provided.
# Run each cell and check the output.
#
# ### Learning outcomes
# By the end of this session, you should be able to:
# - use Jupyter Notebook cells in VS Code
# - create variables using common Python data types
# - apply arithmetic operators
# - work with lists and dictionaries
# - use selection and iteration
# - define simple functions
# - write short Python solutions to small problems

# %% [markdown]
# ## Task 0 – Getting started
#
# Before you begin:
# 1. Run the code cell below.
# 2. Change the text so it prints your own name.
# 3. Run it again.

# %%
print("Hello, my name is ...")

# %% [markdown]
# ## Task 1 – Variables and data types
#
# Create variables called:
# - `name` storing your first name
# - `age` storing your age
# - `course` storing `"Artificial Intelligence"`
# - `likes_python` storing either `True` or `False`
#
# Then print each variable on a new line.

# %%
# Write your answer here

# %% [markdown]
# ## Task 2 – Checking data types
#
# Using the variables from Task 1, use `type()` to display the type of each variable.

# %%
# Write your answer here

# %% [markdown]
# ## Task 3 – Arithmetic operators
#
# Create two variables:
# - `a = 15`
# - `b = 4`
#
# Use Python to calculate and print:
# - addition
# - subtraction
# - multiplication
# - division
# - integer division
# - modulus
# - exponentiation (`a` to the power of `b`)

# %%
# Write your answer here

# %% [markdown]
# ## Task 4 – Fix the mistakes
#
# The code below contains errors.
# Correct it so that it runs properly.
#
# **Expected idea:** it should greet the user and print a calculated answer.

# %%
# Fix this code
Name = Andy
number_1 = "10"
number_2 = 5

print("Hello " + name)
print(number_1 + number_2)

# %% [markdown]
# ## Task 5 – Lists
#
# Create a list called `ai_topics` containing:
# - `"search"`
# - `"machine learning"`
# - `"computer vision"`
# - `"NLP"`
#
# Then:
# 1. print the whole list
# 2. print the first item
# 3. print the last item
# 4. add `"robotics"` to the end of the list
# 5. print the updated list

# %%
# Write your answer here

# %% [markdown]
# ## Task 6 – List indexing and slicing
#
# Use the list below to:
# 1. print the second item
# 2. print the third and fourth items together using slicing
# 3. print the list in reverse order using slicing

# %%
topics = ["python", "data", "logic", "models", "agents"]

# Write your answer here

# %% [markdown]
# ## Task 7 – Dictionaries
#
# Create a dictionary called `student` with the following keys and values:
# - `"name"` → your name
# - `"level"` → 5
# - `"module"` → `"Artificial Intelligence"`
# - `"skills"` → a list with at least three skills
#
# Then:
# 1. print the dictionary
# 2. print the value for `"module"`
# 3. print the first skill from `"skills"`

# %%
# Write your answer here

# %% [markdown]
# ## Task 8 – Selection with `if`, `elif`, `else`
#
# Write a program that stores a number in a variable called `mark`.
#
# Rules:
# - if the mark is 70 or above, print `"First"`
# - else if the mark is 60 or above, print `"Upper Second"`
# - else if the mark is 50 or above, print `"Lower Second"`
# - otherwise print `"Needs improvement"`
#
# Test your code with at least two different values.

# %%
# Write your answer here

# %% [markdown]
# ## Task 9 – `for` loops
#
# Write a `for` loop that prints the numbers from 1 to 10.
#
# Then write another `for` loop that prints each item in this list on a new line:
# `["AI", "Python", "Data", "Models"]`

# %%
# Write your answer here

# %% [markdown]
# ## Task 10 – `while` loops
#
# Write a `while` loop that starts at 5 and counts down to 1.
#
# After the loop finishes, print `"Done"`.

# %%
# Write your answer here

# %% [markdown]
# ## Task 11 – Functions
#
# Create a function called `greet_student` that takes one parameter called `name` and prints:
#
# `Welcome to AI, <name>`
#
# Call the function with your own name.

# %%
# Write your answer here

# %% [markdown]
# ## Task 12 – Functions with return values
#
# Create a function called `square_number` that:
# - takes one number as input
# - returns the square of that number
#
# Call the function with `6` and print the result.

# %%
# Write your answer here

# %% [markdown]
# ## Task 13 – Mini problem: total and average
#
# You are given a list of quiz marks:
#
# `marks = [62, 75, 68, 71, 59]`
#
# Write code to:
# 1. print the total
# 2. print the average
# 3. print the highest mark
# 4. print the lowest mark

# %%
marks = [62, 75, 68, 71, 59]

# Write your answer here

# %% [markdown]
# ## Task 14 – List comprehension
#
# Create a new list called `squares` containing the square numbers from 0 to 9 using a list comprehension.
#
# Print the list.

# %%
# Write your answer here

# %% [markdown]
# ## Task 15 – Challenge task
#
# Write a short program that:
# 1. asks the user for their name
# 2. asks for the number of hours they studied this week
# 3. prints a message:
#    - `"Excellent effort"` if the number is 10 or more
#    - `"Good start"` if the number is between 5 and 9
#    - `"Try to build a regular study habit"` otherwise
#
# **Note:** if `input()` does not work well in your environment, create variables instead.

# %%
# Write your answer here

# %% [markdown]
# ## Reflection
#
# Answer these questions in a markdown cell below:
# 1. Which task did you find easiest?
# 2. Which task did you find most challenging?
# 3. What do you need to practise before next session?
