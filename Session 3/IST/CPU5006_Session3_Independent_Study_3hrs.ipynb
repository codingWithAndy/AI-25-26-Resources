# %% [markdown]
# # CPU5006 Session 3: Independent Study Notebook
# ## Rule-Based AI Systems (Approx. 3 hours)
#
# This notebook contains **three hours of independent study tasks** based on Session 3.
#
# ## Aims
# By completing these tasks, you should be able to:
# - explain what a rule-based AI system is
# - identify the parts of a rule-based system
# - write and test simple rules in Python
# - compare forward and backward chaining
# - build and improve a small rule-based AI system
# - reflect on strengths and limitations of symbolic AI
# - connect your work to Assessment S1
#
# ## Suggested time plan
# - **Part 1: Core understanding and recap** — 35 mins
# - **Part 2: Writing and testing rules** — 45 mins
# - **Part 3: Chaining and reasoning tasks** — 35 mins
# - **Part 4: Mini rule-based AI build** — 40 mins
# - **Part 5: Reflection and S1 planning** — 25 mins
#
# Work through the tasks in order.
# Where a task says **SIB**, treat it as stretch / extension work.

# %% [markdown]
# ## Part 1: Core understanding and recap (35 mins)
#
# ### Task 1.1: Key ideas recap
# Answer the following in your own words.
#
# 1. What is a rule-based AI system?
# 2. Why is it also called **symbolic AI**?
# 3. What is one advantage of rule-based AI?
# 4. What is one limitation of rule-based AI?

# %%
# Write your answers here

# %% [markdown]
# ### Task 1.2: Components of a rule-based system
# Complete the table by matching each description to the correct component.
#
# Components:
# - Knowledge Base
# - Inference Engine
# - User Interface
#
# Descriptions:
# - stores rules and facts
# - applies rules to data or facts
# - allows a user to enter information and view responses

# %%
components = {
    "stores rules and facts": "",
    "applies rules to data or facts": "",
    "allows a user to enter information and view responses": ""
}

components

# %% [markdown]
# ### Task 1.3: Short comparison
# Write **2–3 sentences** explaining the difference between:
# - rule-based AI
# - machine learning

# %%
# Write your comparison here

# %% [markdown]
# ### SIB Task 1.4
# Give one real-world example where a **rule-based system** would be more appropriate than a machine learning system, and explain why.

# %%
# Write your answer here

# %% [markdown]
# ## Part 2: Writing and testing rules (45 mins)
#
# ### Task 2.1: Read simple rules
# Look at the code below and predict the outputs **before** running it.

# %%
def respond(message):
    message = message.lower()

    if "hello" in message:
        return "Hello!"
    elif "deadline" in message:
        return "Check the module page."
    elif "bye" in message:
        return "Goodbye!"
    else:
        return "I do not understand."

print(respond("Hello there"))
print(respond("Can you tell me the deadline?"))
print(respond("Bye for now"))
print(respond("What is deep learning?"))

# %% [markdown]
# Write down:
# 1. Which rule matched each input?
# 2. Why does `"Hello there"` still match the greeting rule?

# %%
# Write your answers here

# %% [markdown]
# ### Task 2.2: Complete the missing rule logic
# Finish the function below so that it works as a simple university support bot.
#
# Requirements:
# - greeting rule
# - deadline rule
# - revision rule
# - default response

# %%
def student_support_bot(message):
    message = message.lower().strip()

    # Complete the rules below
    if ________:
        return "Hello! How can I help?"
    elif ________:
        return "Please check the module page for deadlines."
    elif ________:
        return "Try revising in short focused sessions and test yourself regularly."
    else:
        return "I am not sure how to answer that yet."


# Test your bot below
# print(student_support_bot("hello"))

# %% [markdown]
# ### Task 2.3: Build your own small rule set
# Create a function with at least **5 rules** for one of the following domains:
# - student support
# - laptop troubleshooting
# - movie recommendations
# - revision advice
#
# You must include:
# - at least 4 specific rules
# - 1 default response

# %%
def my_rule_based_ai(message):
    # Write your code here
    pass


# Add test calls below

# %% [markdown]
# ### Task 2.4: Testing table
# Create a small test set for your system.
#
# Include:
# - 6 inputs
# - expected output for each
# - actual output for each

# %%
# Example structure
tests = [
    # ("input", "expected output"),
]

# Write code to run your tests here

# %% [markdown]
# ### SIB Task 2.5
# Improve your system by adding:
# - synonyms, or
# - one rule with more than one condition

# %%
# Add your improved version here

# %% [markdown]
# ## Part 3: Chaining and reasoning tasks (35 mins)
#
# ### Task 3.1: Forward or backward chaining?
# Decide whether each scenario is best described as **forward chaining** or **backward chaining**.
#
# 1. Start with symptoms and work towards a diagnosis.
# 2. Start with the goal “loan approved” and check which facts must be true.
# 3. Start with known weather facts and work towards a fire warning.
# 4. Start with a suspected fault and check whether evidence supports it.

# %%
answers = {
    1: "",
    2: "",
    3: "",
    4: ""
}

answers

# %% [markdown]
# ### Task 3.2: Explain your thinking
# Write **one sentence each** explaining why you chose forward or backward chaining for the four scenarios above.

# %%
# Write your explanations here

# %% [markdown]
# ### Task 3.3: Manual forward chaining
# You are given these facts:
#
# - temperature = high
# - humidity = low
#
# And these rules:
#
# 1. IF temperature is high THEN risk = medium
# 2. IF humidity is low AND risk = medium THEN fire_warning = true
# 3. IF fire_warning = true THEN action = "Send alert"
#
# Work out:
# - which rule fires first
# - what new fact is produced
# - what the final action is

# %%
# Write your answers here

# %% [markdown]
# ### Task 3.4: Implement the forward-chaining logic in Python
# Use variables and `if` statements to model the rules above.

# %%
temperature = "high"
humidity = "low"

risk = None
fire_warning = None
action = None

# Write your rule logic here

print("risk =", risk)
print("fire_warning =", fire_warning)
print("action =", action)

# %% [markdown]
# ### SIB Task 3.5
# Create your own **three-step forward chain** for a different domain, for example:
# - student support
# - home heating
# - study planning

# %%
# Write your own chain and implementation here

# %% [markdown]
# ## Part 4: Mini rule-based AI build (40 mins)
#
# ### Task 4.1: Build a tiny expert system
# Choose one domain:
# - revision support
# - module help
# - laptop troubleshooting
# - simple symptom checker
# - film suggestion helper
#
# Design:
# - 4 inputs or keywords
# - 4 rules
# - 3 possible outputs
#
# Write your plan first.

# %%
domain = ""
keywords = []
rules_summary = []
possible_outputs = []

print(domain, keywords, rules_summary, possible_outputs)

# %% [markdown]
# ### Task 4.2: Implement your expert system in Python
# Now turn your plan into code.

# %%
class MiniExpertSystem:
    def respond(self, message):
        # Write your AI logic here
        pass


ai = MiniExpertSystem()

# Add at least 6 test calls below

# %% [markdown]
# ### Task 4.3: Evaluate your system
# Answer the following:
#
# 1. What does your system do well?
# 2. Where does it fail?
# 3. What kinds of user input are difficult for it?
# 4. How could you improve it?

# %%
# Write your evaluation here

# %% [markdown]
# ### SIB Task 4.4
# Refactor your system so that it uses:
# - a dictionary of keywords and responses, or
# - helper functions to make the code clearer

# %%
# Write your improved version here

# %% [markdown]
# ## Part 5: Reflection and S1 planning (25 mins)
#
# ### Task 5.1: Link to the lecture
# Complete the sentences:
#
# - Rule-based AI is useful when...
# - Rule-based AI may struggle when...

# %%
# Complete the sentences here

# %% [markdown]
# ### Task 5.2: Connect to Assessment S1
# Draft ideas for a possible S1 rule-based AI experiment.
#
# Complete:
# - possible topic
# - dataset
# - possible rules
# - possible evaluation measure
# - why this would make a good investigation

# %%
topic = ""
dataset = ""
possible_rules = []
evaluation_measure = ""
why_good_investigation = ""

print("Topic:", topic)
print("Dataset:", dataset)
print("Possible rules:", possible_rules)
print("Evaluation measure:", evaluation_measure)
print("Why:", why_good_investigation)

# %% [markdown]
# ### Task 5.3: Write a short methodology outline
# Write **120–180 words** describing how you would implement and test your proposed rule-based AI system.

# %%
# Write your methodology outline here

# %% [markdown]
# ### Final reflection
# Answer briefly:
#
# 1. What did you find easiest in this notebook?
# 2. What did you find most difficult?
# 3. What do you still need to practise before S1?

# %%
# Write your reflection here

# %% [markdown]
# ## Optional extension: Flask connection task
#
# If you have completed the work above, use the separate Flask starter materials to:
# - run the app
# - add at least 3 of your own rules
# - test the app with 5 different inputs
# - identify the knowledge base, inference engine, and user interface
