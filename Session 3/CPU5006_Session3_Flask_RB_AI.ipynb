# %% [markdown]
# # CPU5006 Session 3: Flask Rule-Based AI Task
# ## Starter Notebook
#
# This is a separate scaffolded task.
#
# You will build a small **rule-based AI system with a Flask front end**.
#
# ### Your job
# - keep the Flask structure
# - complete the missing **AI logic**
# - test the system with different user inputs
#
# ### Suggested domains
# - student support chatbot
# - simple symptom checker
# - laptop troubleshooting helper
# - revision advice chatbot

# %% [markdown]
# ## Step 1: Install Flask
#
# Run this in a terminal if Flask is not already installed:
#
# ```bash
# pip install flask
# ```

# %% [markdown]
# ## Step 2: Suggested project structure
#
# ```text
# rb_ai_flask/
# ├── app.py
# └── templates/
#     └── index.html
# ```

# %% [markdown]
# ## Step 3: Starter code for `app.py`
#
# Read the code carefully.
# The Flask app is mostly complete, but the **AI logic is unfinished**.

# %%
from flask import Flask, render_template, request

app = Flask(__name__)

class RuleBasedAI:
    def respond(self, message):
        message = message.lower().strip()

        # TODO:
        # Add your AI logic below using if / elif / else
        #
        # Example ideas:
        # if "hello" in message:
        #     return "Hello! How can I help?"
        #
        # elif "deadline" in message:
        #     return "Please check Minerva for current deadlines."
        #
        # elif ...
        #
        # else:
        #     return "I'm sorry, I do not understand that question yet."

        pass

ai = RuleBasedAI()

@app.route("/", methods=["GET", "POST"])
def index():
    response = ""

    if request.method == "POST":
        user_message = request.form.get("message", "")
        response = ai.respond(user_message)

    return render_template("index.html", response=response)

if __name__ == "__main__":
    app.run(debug=True)

# %% [markdown]
# ## Step 4: Starter code for `templates/index.html`
#
# Create a file called `index.html` inside the `templates` folder and paste this in.

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Rule-Based AI</title>
    <style>
        body {
            font-family: Arial, sans-serif;
            max-width: 700px;
            margin: 40px auto;
            padding: 20px;
        }
        textarea, input[type="text"] {
            width: 100%;
            padding: 10px;
            margin-top: 10px;
            margin-bottom: 10px;
        }
        button {
            padding: 10px 16px;
            cursor: pointer;
        }
        .response {
            margin-top: 20px;
            padding: 15px;
            border: 1px solid #ccc;
            background: #f4f4f4;
        }
    </style>
</head>
<body>
    <h1>Rule-Based AI Demo</h1>
    <form method="POST">
        <label for="message">Ask a question:</label>
        <input type="text" id="message" name="message" placeholder="Type your message here">
        <button type="submit">Send</button>
    </form>

    {% if response %}
    <div class="response">
        <strong>AI response:</strong>
        <p>{{ response }}</p>
    </div>
    {% endif %}
</body>
</html>

# %% [markdown]
# ## Step 5: Your task
#
# Complete the `respond()` method so that your AI can handle at least **4 rules** and **1 default response**.
#
# ### Minimum requirements
# - one greeting rule
# - one information rule
# - one help/advice rule
# - one farewell rule
# - one default fallback
#
# ### Example domains
# - university module assistant
# - revision support bot
# - device troubleshooting assistant

# %%
# Draft your rules here before editing app.py

# Rule 1:
# IF ...

# Rule 2:
# IF ...

# Rule 3:
# IF ...

# Rule 4:
# IF ...

# Default:
# ELSE ...

# %% [markdown]
# ## Step 6: Test plan
#
# Before running your Flask app, write 5 test inputs and the expected outputs.

# %%
tests = [
    # ("input", "expected output"),
]

tests

# %% [markdown]
# ## Step 7: Extension task (SIB)
#
# Improve the AI by adding one of these:
# - keyword synonyms
# - multiple-condition rules
# - a short explanation for each answer
# - category-based responses

# %%
# Example extension ideas:
#
# if "exam" in message or "test" in message:
#     return "Revision support ..."
#
# if "deadline" in message and "coursework" in message:
#     return "..."

# %% [markdown]
# ## Optional stronger scaffold
#
# If you want a little more help, use this version and complete the gaps.

# %%
from flask import Flask, render_template, request

app = Flask(__name__)

class RuleBasedAI:
    def respond(self, message):
        message = message.lower().strip()

        if ________:
            return "Hello! How can I help you today?"
        elif ________:
            return "You can check the module page for deadlines and resources."
        elif ________:
            return "Try breaking your problem into smaller steps and test one rule at a time."
        elif ________:
            return "Goodbye!"
        else:
            return "I'm sorry, I don't understand that yet."

ai = RuleBasedAI()

@app.route("/", methods=["GET", "POST"])
def index():
    response = ""
    if request.method == "POST":
        user_message = request.form.get("message", "")
        response = ai.respond(user_message)
    return render_template("index.html", response=response)

if __name__ == "__main__":
    app.run(debug=True)

# %% [markdown]
# ## Reflection
#
# After completing the task, answer:
#
# 1. What part of this system is the **user interface**?
# 2. What part is acting as the **knowledge base**?
# 3. What part is acting as the **inference engine**?
# 4. What are the main limitations of your AI?

# %%
# Write your answers here
